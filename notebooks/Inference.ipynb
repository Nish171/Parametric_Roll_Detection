# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("..")

# %%
from InferenceUtils import *
from pathlib import Path

# %%
RUN_NAME = "AQUA_RUNS"
MODEL_NUMBER = "04"
PATH_TO_MODEL_DIR = Path('models') / RUN_NAME / MODEL_NUMBER

val_dir = PATH_TO_MODEL_DIR / "val"
test_dir = PATH_TO_MODEL_DIR / "test"

val_in, val_true, val_pred = load_inference(val_dir)
test_in, test_true, test_pred = load_inference(test_dir)

# %%
plot_inference(val_in, val_true, val_pred, nos=[0,5,10,20,30,40,50], cut=1)

# %%
plot_inference(test_in, test_true, test_pred, nos=[10,20,30], cut=1)
