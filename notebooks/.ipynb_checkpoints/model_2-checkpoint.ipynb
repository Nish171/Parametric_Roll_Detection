# %%
import os
os.chdir('..')

# %%
pwd
# Out:
# 'C:\\Users\\nimee\\OneDrive\\Documents\\DDP\\Parametric_Roll_Detection'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.data.Dataset import Dataset as DS
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# from src.models.Model_OneShotDNN import OneShotDNN

# %%
# Dataset generator
n = 10
m = 5
hop = 0.25
input_dim   = 30 * n
pred_dim    = 30 * m
shift       = pred_dim
batch_size  = 16
Data        = DS(
                input_dim, 
                pred_dim, 
                shift, 
                skip=0.25, 
                hop=hop, 
                batch_size=batch_size,
                in_cols=['roll', 'pitch']
                )

# %%
Data.Train.element_spec
# Out:
# (TensorSpec(shape=(None, 1200, 2), dtype=tf.float64, name=None),
#  TensorSpec(shape=(None, 600, 1), dtype=tf.float64, name=None))

# %%
# Loss functions
# Regression loss
MSE_loss = tf.keras.losses.MeanSquaredError()

# Metrics
# Regression metrics
MAPE = tf.keras.metrics.MeanAbsolutePercentageError()
MAE = tf.keras.metrics.MeanAbsoluteError()

# %%
INPUT_DIM = Data.xshape
OUTPUT_DIM = Data.yshape

# %%
print('Input dim:', INPUT_DIM)
print('Output dim:', OUTPUT_DIM)
# Out:
# Input dim: [1200, 2]
# Output dim: [600, 1]

# %%
norm = tf.keras.layers.Normalization(input_shape=INPUT_DIM, axis=-1)
x_ds = Data.Train.map(lambda x, y: x)
norm.adapt(x_ds)

# %%
norm.variance.numpy()
# Out:
# array([[[15.116447  ,  0.60266036]]], dtype=float32)

# %%
acti = 'tanh'

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=INPUT_DIM))
# model.add(norm)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1024, activation=acti))
model.add(tf.keras.layers.Dense(1024, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(OUTPUT_DIM[0]))

# %%
model.compile(optimizer='adam', loss=MSE_loss, metrics=[MAPE, MAE])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 2400)              0
#
#  dense_18 (Dense)            (None, 1024)              2458624
#
#  dense_19 (Dense)            (None, 1024)              1049600
#
#  dense_20 (Dense)            (None, 512)               524800
#
#  dense_21 (Dense)            (None, 512)               262656
#
#  dense_22 (Dense)            (None, 512)               262656
#
#  dense_23 (Dense)            (None, 600)               307800
#
# =================================================================
# Total params: 4,866,136
# Trainable params: 4,866,136
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=10,
                                                    mode='min')

# %%
model.fit(Data.Train, epochs=100, validation_data=Data.Val, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 429/429 [==============================] - 21s 48ms/step - loss: 14.6048 - mean_absolute_percentage_error: 623.5654 - mean_absolute_error: 2.0308 - val_loss: 9.1582 - val_mean_absolute_percentage_error: 521.8699 - val_mean_absolute_error: 1.6111
# Epoch 2/100
# 429/429 [==============================] - 21s 50ms/step - loss: 14.5458 - mean_absolute_percentage_error: 680.0574 - mean_absolute_error: 2.0472 - val_loss: 8.8669 - val_mean_absolute_percentage_error: 487.8422 - val_mean_absolute_error: 1.5689
# Epoch 3/100
# 429/429 [==============================] - 21s 48ms/step - loss: 14.3139 - mean_absolute_percentage_error: 680.3942 - mean_absolute_error: 2.0339 - val_loss: 8.5513 - val_mean_absolute_percentage_error: 482.8152 - val_mean_absolute_error: 1.5434
# Epoch 4/100
# 429/429 [==============================] - 20s 47ms/step - loss: 14.4277 - mean_absolute_percentage_error: 680.6069 - mean_absolute_error: 2.0385 - val_loss: 8.9473 - val_mean_absolute_percentage_error: 425.8905 - val_mean_absolute_error: 1.5679
# Epoch 5/100
# 429/429 [==============================] - 19s 45ms/step - loss: 14.4597 - mean_absolute_percentage_error: 641.1989 - mean_absolute_error: 2.0325 - val_loss: 8.7319 - val_mean_absolute_percentage_error: 462.1247 - val_mean_absolute_error: 1.5258
# Epoch 6/100
# 429/429 [==============================] - 20s 47ms/step - loss: 14.2842 - mean_absolute_percentage_error: 686.8873 - mean_absolute_error: 2.0334 - val_loss: 8.7960 - val_mean_absolute_percentage_error: 449.7881 - val_mean_absolute_error: 1.5573
# Epoch 7/100
# 429/429 [==============================] - 20s 47ms/step - loss: 14.1625 - mean_absolute_percentage_error: 763.7741 - mean_absolute_error: 2.0272 - val_loss: 8.8245 - val_mean_absolute_percentage_error: 467.6019 - val_mean_absolute_error: 1.5711
# Epoch 8/100
# 429/429 [==============================] - 20s 46ms/step - loss: 13.9559 - mean_absolute_percentage_error: 734.3179 - mean_absolute_error: 2.0080 - val_loss: 8.7627 - val_mean_absolute_percentage_error: 463.1301 - val_mean_absolute_error: 1.5616
# Epoch 9/100
# 429/429 [==============================] - 19s 45ms/step - loss: 13.6768 - mean_absolute_percentage_error: 699.8380 - mean_absolute_error: 1.9712 - val_loss: 8.6425 - val_mean_absolute_percentage_error: 437.7290 - val_mean_absolute_error: 1.5416
# Epoch 10/100
# 429/429 [==============================] - 20s 48ms/step - loss: 13.5968 - mean_absolute_percentage_error: 724.5519 - mean_absolute_error: 1.9714 - val_loss: 8.4313 - val_mean_absolute_percentage_error: 495.0669 - val_mean_absolute_error: 1.5229
# Epoch 11/100
# 429/429 [==============================] - 19s 45ms/step - loss: 13.5248 - mean_absolute_percentage_error: 758.8959 - mean_absolute_error: 1.9671 - val_loss: 8.1856 - val_mean_absolute_percentage_error: 507.4858 - val_mean_absolute_error: 1.5074
# Epoch 12/100
# 429/429 [==============================] - 21s 48ms/step - loss: 13.2737 - mean_absolute_percentage_error: 740.9460 - mean_absolute_error: 1.9379 - val_loss: 8.1942 - val_mean_absolute_percentage_error: 525.1008 - val_mean_absolute_error: 1.5068
# Epoch 13/100
# 429/429 [==============================] - 20s 47ms/step - loss: 13.1968 - mean_absolute_percentage_error: 710.0079 - mean_absolute_error: 1.9314 - val_loss: 7.8514 - val_mean_absolute_percentage_error: 514.1433 - val_mean_absolute_error: 1.4516
# Epoch 14/100
# 429/429 [==============================] - 20s 46ms/step - loss: 13.1783 - mean_absolute_percentage_error: 715.5076 - mean_absolute_error: 1.9255 - val_loss: 7.9122 - val_mean_absolute_percentage_error: 493.8154 - val_mean_absolute_error: 1.4682
# Epoch 15/100
# 429/429 [==============================] - 20s 46ms/step - loss: 12.9031 - mean_absolute_percentage_error: 734.4711 - mean_absolute_error: 1.8988 - val_loss: 7.9486 - val_mean_absolute_percentage_error: 556.0622 - val_mean_absolute_error: 1.4627
# Epoch 16/100
# 429/429 [==============================] - 20s 46ms/step - loss: 12.8530 - mean_absolute_percentage_error: 697.0065 - mean_absolute_error: 1.8885 - val_loss: 7.7483 - val_mean_absolute_percentage_error: 530.5692 - val_mean_absolute_error: 1.4449
# Epoch 17/100
# 429/429 [==============================] - 19s 45ms/step - loss: 12.6842 - mean_absolute_percentage_error: 717.4926 - mean_absolute_error: 1.8705 - val_loss: 7.6797 - val_mean_absolute_percentage_error: 546.6133 - val_mean_absolute_error: 1.4496
# Epoch 18/100
# 429/429 [==============================] - 19s 45ms/step - loss: 12.5971 - mean_absolute_percentage_error: 693.6956 - mean_absolute_error: 1.8600 - val_loss: 7.5327 - val_mean_absolute_percentage_error: 544.4729 - val_mean_absolute_error: 1.4286
# Epoch 19/100
# 429/429 [==============================] - 20s 45ms/step - loss: 12.4524 - mean_absolute_percentage_error: 668.2625 - mean_absolute_error: 1.8490 - val_loss: 7.4477 - val_mean_absolute_percentage_error: 520.3000 - val_mean_absolute_error: 1.4043
# Epoch 20/100
# 429/429 [==============================] - 20s 46ms/step - loss: 12.2812 - mean_absolute_percentage_error: 689.8284 - mean_absolute_error: 1.8358 - val_loss: 7.3920 - val_mean_absolute_percentage_error: 554.4597 - val_mean_absolute_error: 1.3974
# Epoch 21/100
# 429/429 [==============================] - 19s 45ms/step - loss: 12.2054 - mean_absolute_percentage_error: 637.1343 - mean_absolute_error: 1.8178 - val_loss: 7.4397 - val_mean_absolute_percentage_error: 604.0457 - val_mean_absolute_error: 1.4293
# Epoch 22/100
# 429/429 [==============================] - 20s 46ms/step - loss: 12.0897 - mean_absolute_percentage_error: 716.0314 - mean_absolute_error: 1.8232 - val_loss: 7.3805 - val_mean_absolute_percentage_error: 614.3339 - val_mean_absolute_error: 1.4249
# Epoch 23/100
# 429/429 [==============================] - 21s 48ms/step - loss: 11.9878 - mean_absolute_percentage_error: 706.0313 - mean_absolute_error: 1.8121 - val_loss: 7.2593 - val_mean_absolute_percentage_error: 633.5569 - val_mean_absolute_error: 1.4107
# Epoch 24/100
# 429/429 [==============================] - 20s 46ms/step - loss: 11.9975 - mean_absolute_percentage_error: 690.5424 - mean_absolute_error: 1.8159 - val_loss: 7.3148 - val_mean_absolute_percentage_error: 622.1848 - val_mean_absolute_error: 1.4115
# Epoch 25/100
# 429/429 [==============================] - 20s 46ms/step - loss: 11.7692 - mean_absolute_percentage_error: 673.0556 - mean_absolute_error: 1.7941 - val_loss: 7.3919 - val_mean_absolute_percentage_error: 604.4183 - val_mean_absolute_error: 1.4166
# Epoch 26/100
# 429/429 [==============================] - 21s 50ms/step - loss: 11.6413 - mean_absolute_percentage_error: 672.8681 - mean_absolute_error: 1.7793 - val_loss: 7.4441 - val_mean_absolute_percentage_error: 570.2202 - val_mean_absolute_error: 1.4248
# Epoch 27/100
# 429/429 [==============================] - 20s 47ms/step - loss: 11.5732 - mean_absolute_percentage_error: 636.9406 - mean_absolute_error: 1.7761 - val_loss: 7.3439 - val_mean_absolute_percentage_error: 615.8182 - val_mean_absolute_error: 1.4196
# Epoch 28/100
# 429/429 [==============================] - 20s 45ms/step - loss: 11.6060 - mean_absolute_percentage_error: 643.4896 - mean_absolute_error: 1.7818 - val_loss: 7.3158 - val_mean_absolute_percentage_error: 581.0132 - val_mean_absolute_error: 1.4059
# Epoch 29/100
# 429/429 [==============================] - 20s 46ms/step - loss: 11.3530 - mean_absolute_percentage_error: 671.0708 - mean_absolute_error: 1.7619 - val_loss: 7.3698 - val_mean_absolute_percentage_error: 636.0893 - val_mean_absolute_error: 1.4316
# Epoch 30/100
# 429/429 [==============================] - 20s 46ms/step - loss: 11.3872 - mean_absolute_percentage_error: 690.0386 - mean_absolute_error: 1.7673 - val_loss: 7.2159 - val_mean_absolute_percentage_error: 681.8514 - val_mean_absolute_error: 1.4138
# Epoch 31/100
# 429/429 [==============================] - 20s 46ms/step - loss: 11.3042 - mean_absolute_percentage_error: 671.2487 - mean_absolute_error: 1.7655 - val_loss: 7.4195 - val_mean_absolute_percentage_error: 625.2394 - val_mean_absolute_error: 1.4499
# Epoch 32/100
# 429/429 [==============================] - 20s 47ms/step - loss: 11.2101 - mean_absolute_percentage_error: 653.9252 - mean_absolute_error: 1.7537 - val_loss: 7.3248 - val_mean_absolute_percentage_error: 645.9862 - val_mean_absolute_error: 1.4338
# Epoch 33/100
# 429/429 [==============================] - 24s 55ms/step - loss: 11.1247 - mean_absolute_percentage_error: 646.7057 - mean_absolute_error: 1.7501 - val_loss: 7.3066 - val_mean_absolute_percentage_error: 662.6854 - val_mean_absolute_error: 1.4192
# Epoch 34/100
# 429/429 [==============================] - 28s 64ms/step - loss: 11.1657 - mean_absolute_percentage_error: 652.6163 - mean_absolute_error: 1.7637 - val_loss: 7.2793 - val_mean_absolute_percentage_error: 689.1261 - val_mean_absolute_error: 1.4363
# Epoch 35/100
# 429/429 [==============================] - 27s 63ms/step - loss: 11.1010 - mean_absolute_percentage_error: 670.7257 - mean_absolute_error: 1.7598 - val_loss: 7.3964 - val_mean_absolute_percentage_error: 709.1174 - val_mean_absolute_error: 1.4369
# Epoch 36/100
# 429/429 [==============================] - 28s 65ms/step - loss: 10.9353 - mean_absolute_percentage_error: 707.1567 - mean_absolute_error: 1.7402 - val_loss: 7.3161 - val_mean_absolute_percentage_error: 703.6677 - val_mean_absolute_error: 1.4361
# Epoch 37/100
# 429/429 [==============================] - 27s 63ms/step - loss: 10.9143 - mean_absolute_percentage_error: 680.0576 - mean_absolute_error: 1.7470 - val_loss: 7.1969 - val_mean_absolute_percentage_error: 670.4935 - val_mean_absolute_error: 1.4205
# Epoch 38/100
# 429/429 [==============================] - 27s 63ms/step - loss: 10.8525 - mean_absolute_percentage_error: 723.5453 - mean_absolute_error: 1.7389 - val_loss: 7.3450 - val_mean_absolute_percentage_error: 690.0149 - val_mean_absolute_error: 1.4305
# Epoch 39/100
# 429/429 [==============================] - 27s 64ms/step - loss: 10.8794 - mean_absolute_percentage_error: 677.0241 - mean_absolute_error: 1.7498 - val_loss: 7.2931 - val_mean_absolute_percentage_error: 694.1602 - val_mean_absolute_error: 1.4392
# Epoch 40/100
# 429/429 [==============================] - 27s 63ms/step - loss: 10.7564 - mean_absolute_percentage_error: 680.6674 - mean_absolute_error: 1.7407 - val_loss: 7.3363 - val_mean_absolute_percentage_error: 657.6373 - val_mean_absolute_error: 1.4354
# Epoch 41/100
# 429/429 [==============================] - 28s 65ms/step - loss: 10.6562 - mean_absolute_percentage_error: 725.0344 - mean_absolute_error: 1.7265 - val_loss: 7.2784 - val_mean_absolute_percentage_error: 718.8008 - val_mean_absolute_error: 1.4369
# Epoch 42/100
# 429/429 [==============================] - 27s 64ms/step - loss: 10.4995 - mean_absolute_percentage_error: 726.8490 - mean_absolute_error: 1.7208 - val_loss: 7.2488 - val_mean_absolute_percentage_error: 773.9556 - val_mean_absolute_error: 1.4462
# Epoch 43/100
# 429/429 [==============================] - 28s 64ms/step - loss: 10.4624 - mean_absolute_percentage_error: 705.3336 - mean_absolute_error: 1.7173 - val_loss: 7.5276 - val_mean_absolute_percentage_error: 754.4325 - val_mean_absolute_error: 1.4611
# Epoch 44/100
# 429/429 [==============================] - 28s 64ms/step - loss: 10.4310 - mean_absolute_percentage_error: 704.1697 - mean_absolute_error: 1.7117 - val_loss: 7.2514 - val_mean_absolute_percentage_error: 740.3458 - val_mean_absolute_error: 1.4571
# Epoch 45/100
# 429/429 [==============================] - 28s 64ms/step - loss: 10.4770 - mean_absolute_percentage_error: 735.0050 - mean_absolute_error: 1.7294 - val_loss: 7.2145 - val_mean_absolute_percentage_error: 726.7501 - val_mean_absolute_error: 1.4511
# Epoch 46/100
# 429/429 [==============================] - 27s 64ms/step - loss: 10.4457 - mean_absolute_percentage_error: 730.3295 - mean_absolute_error: 1.7126 - val_loss: 7.4172 - val_mean_absolute_percentage_error: 758.3077 - val_mean_absolute_error: 1.4652
# Epoch 47/100
# 429/429 [==============================] - 27s 63ms/step - loss: 10.3832 - mean_absolute_percentage_error: 723.5685 - mean_absolute_error: 1.7038 - val_loss: 7.2742 - val_mean_absolute_percentage_error: 776.4395 - val_mean_absolute_error: 1.4512

# %%
Data.plot_example(49, model, max_plots=5)

# %%
for x, y in Data.Example(50):
    y_pred = model(x)
    print(x.shape)
    print(max(y[0,:]))
    print(y.shape, y_pred.shape)
    print(MAE(y, y_pred))
    plt.plot(y_pred[0,:], label='y')
    plt.show()
    break
# Out:
# (16, 1200, 2)
# tf.Tensor([6.91228834], shape=(1,), dtype=float64)
# (16, 600, 1) (16, 600)
# tf.Tensor(1.4001782, shape=(), dtype=float32)

# %%
for x, y in Data.Example(50):
    x_norm = norm(x)
    y_pred = model(x_norm)
    print(x_norm.shape)
    plt.plot(x[0,:,0], label='x')
    plt.plot(x_norm[0,:,0], label='x_norm')
    plt.plot(y_pred[0,:])
    plt.plot(y[0,:])
    plt.show()
    break
# Out:
# (16, 1200, 2)

# %%
oneshot_dnn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(INPUT_DIM,)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_DIM, activation='linear')
])

# %%
MAX_EPOCHS_TRAINING = 50

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  lr_scheduler = tf.keras.callbacks.LearningRateScheduler(
      lambda epoch: 1e-5 * 10**(epoch / 4))

  model.compile(loss=MSE_loss,
                optimizer=tf.optimizers.Adam(learning_rate=1e-5),
                metrics=[MAPE, MAE])

  history = model.fit(window.Train, epochs=MAX_EPOCHS_TRAINING,
                      validation_data=window.Val,
                      callbacks=[early_stopping])
  return history

# %%
history_training = compile_and_fit(oneshot_dnn_model, data)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\nimee\OneDrive\Documents\DDP\Parametric_Roll_Detection\notebooks\model_2.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000014?line=0'>1</a> history_training = compile_and_fit(oneshot_dnn_model, data)
#
# c:\Users\nimee\OneDrive\Documents\DDP\Parametric_Roll_Detection\notebooks\model_2.ipynb Cell 14' in compile_and_fit(model, window, patience)
#       <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=7'>8</a> lr_scheduler = tf.keras.callbacks.LearningRateScheduler(
#       <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=8'>9</a>     lambda epoch: 1e-5 * 10**(epoch / 4))
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=10'>11</a> model.compile(loss=MSE_loss,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=11'>12</a>               optimizer=tf.optimizers.Adam(learning_rate=1e-5),
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=12'>13</a>               metrics=[MAPE, MAE])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=14'>15</a> history = model.fit(window.Train, epochs=MAX_EPOCHS_TRAINING,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=15'>16</a>                     validation_data=window.Val,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=16'>17</a>                     callbacks=[early_stopping])
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=17'>18</a> return history
#
# File c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1144'>1145</a> except Exception as e:  # pylint:disable=broad-except
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1145'>1146</a>   if hasattr(e, "ag_error_metadata"):
# -> <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1146'>1147</a>     raise e.ag_error_metadata.to_exception(e)
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1147'>1148</a>   else:
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1148'>1149</a>     raise
#
# ValueError: in user code:
#
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 1329, in mean_squared_error
#         return backend.mean(tf.math.squared_difference(y_pred, y_true), axis=-1)
#
#     ValueError: Dimensions must be equal, but are 120 and 60 for '{{node mean_squared_error/SquaredDifference}} = SquaredDifference[T=DT_FLOAT](my_model/dense_4/BiasAdd, Cast)' with input shapes: [?,120,60], [?,60,1].

# %%
val_performance = model.evaluate(Data.Val)
test_performance = model.evaluate(Data.Test)
# Out:
# 53/53 [==============================] - 1s 23ms/step - loss: 5.6095 - mean_absolute_percentage_error: 453.1004 - mean_absolute_error: 1.2141
# 62/62 [==============================] - 2s 23ms/step - loss: 7.9224 - mean_absolute_percentage_error: 415.3475 - mean_absolute_error: 1.4855

# %%
print('Validation MSE_loss: {:.2f}'.format(val_performance[0]))
print('Validation MAPE:     {:.2f}'.format(val_performance[1]))
print('Validation MAE:      {:.2f}'.format(val_performance[2]))
print('Test MSE_loss:       {:.2f}'.format(test_performance[0]))
print('Test MAPE:           {:.2f}'.format(test_performance[1]))
print('Test MAE:            {:.2f}'.format(test_performance[2]))
# Out:
# Validation MSE_loss: 5.61
# Validation MAPE:     453.10
# Validation MAE:      1.21
# Test MSE_loss:       7.92
# Test MAPE:           415.35
# Test MAE:            1.49

# %%
model.save('models/oneshot_dnn_model')
# Out:
# INFO:tensorflow:Assets written to: models/oneshot_dnn_model\assets
