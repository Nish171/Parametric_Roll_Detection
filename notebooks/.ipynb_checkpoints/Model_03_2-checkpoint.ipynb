# %% [markdown]
# SETUP

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext tensorboard

# %%
import os
os.chdir('..')
os.add_dll_directory("C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.2/bin")   # Run only if necessary

from src.data.Dataset import Dataset as DS
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Check if GPU is available

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# DATASET

# %%
# Dataset generator

n = 10
m = 5
hop = 1/1200
input_dim   = 30 * n
pred_dim    = 0.25
shift       = pred_dim
batch_size  = 256
Data        = DS(
                input_dim, 
                pred_dim, 
                shift, 
                skip=0.25, 
                hop=hop, 
                batch_size=batch_size,
                in_cols=['roll','heave','pitch','wave']
                )

# %%
Data.Train.element_spec
# Out:
# (TensorSpec(shape=(None, 1200, 4), dtype=tf.float64, name=None),
#  TensorSpec(shape=(None, 1, 1), dtype=tf.float64, name=None))

# %%
INPUT_DIM = Data.xshape
OUTPUT_DIM = Data.yshape

print('Input dim:', INPUT_DIM)
print('Output dim:', OUTPUT_DIM)
# Out:
# Input dim: [1200, 4]
# Output dim: [1, 1]

# %% [markdown]
# MODEL

# %%
# Loss functions

# Regression loss
MSE_loss = tf.keras.losses.MeanSquaredError()
MAE_loss = tf.keras.losses.MeanAbsoluteError()

# Metrics

# Regression metrics
MAPE = tf.keras.metrics.MeanAbsolutePercentageError()
MAE = tf.keras.metrics.MeanAbsoluteError()

# %%
# norm = tf.keras.layers.Normalization(input_shape=INPUT_DIM, axis=-1)
# x_ds = Data.Train.map(lambda x, y: x)
# norm.adapt(x_ds)

# %%
# Define model here

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=INPUT_DIM),
    tf.keras.layers.LSTM(units=256, return_sequences=True),
    tf.keras.layers.LSTM(units=64, return_sequences=True),
    tf.keras.layers.LSTM(units=32, return_sequences=False),
    tf.keras.layers.Dense(32, activation='tanh'),
    tf.keras.layers.Dense(OUTPUT_DIM[0])
])

# %%
# Compile model

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss=MSE_loss, metrics=[MAPE, MAE])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1200, 256)         267264
#
#  lstm_1 (LSTM)               (None, 1200, 64)          82176
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 362,945
# Trainable params: 362,945
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Check if model is working and the output shape
Data.batch_size = 256

for x, y in Data.Train.take(1):
    out = model(x)
    print(out.shape)
# Out:
# (256, 1)

# %% [markdown]
# TRAINING

# %%
# Defining the required callbacks
from datetime import datetime

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=7,
                                                    mode='min')

checkpoint_filepath = 'models/RNN/09/model'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.000001)

logdir = "models/RNN/09/logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir, update_freq=500)

# %%
logdir = 'models/RNN/08/metrics'

# %tensorboard --logdir models/RNN/09/logs
# Out:
# Reusing TensorBoard on port 6006 (pid 22776), started 0:01:36 ago. (Use '!kill 22776' to kill it.)
#       <iframe id="tensorboard-frame-dbd8483e91c6224" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dbd8483e91c6224");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Model training

history = model.fit(Data.Val, epochs=100, validation_data=Data.Test, callbacks=[early_stopping, model_checkpoint_callback, tensorboard_callback])
# Out:
# Epoch 1/100
#     994/Unknown - 580s 579ms/step - loss: 7.2361e-05 - mean_absolute_percentage_error: 35.6298 - mean_absolute_error: 0.0032
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000253700B0F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002536D7A7AF0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000025370093B20> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 994/994 [==============================] - 1006s 1s/step - loss: 7.2361e-05 - mean_absolute_percentage_error: 35.6298 - mean_absolute_error: 0.0032 - val_loss: 3.2086e-06 - val_mean_absolute_percentage_error: 8.4705 - val_mean_absolute_error: 7.8031e-04
# Epoch 2/100
# 994/994 [==============================] - ETA: 0s - loss: 1.7239e-05 - mean_absolute_percentage_error: 16.4667 - mean_absolute_error: 0.0014
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000253700B0F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002536D7A7AF0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000025370093B20> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 994/994 [==============================] - 1004s 1s/step - loss: 1.7239e-05 - mean_absolute_percentage_error: 16.4667 - mean_absolute_error: 0.0014 - val_loss: 1.5546e-06 - val_mean_absolute_percentage_error: 5.0622 - val_mean_absolute_error: 5.3830e-04
# Epoch 3/100
# 994/994 [==============================] - ETA: 0s - loss: 2.9918e-06 - mean_absolute_percentage_error: 22.7665 - mean_absolute_error: 7.4455e-04
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# INFO:tensorflow:Assets written to: models/RNN/09\model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000253700B0F70> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002536D7A7AF0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000025370093B20> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 994/994 [==============================] - 1001s 1s/step - loss: 2.9918e-06 - mean_absolute_percentage_error: 22.7665 - mean_absolute_error: 7.4455e-04 - val_loss: 8.2397e-07 - val_mean_absolute_percentage_error: 4.5520 - val_mean_absolute_error: 3.9765e-04
# Epoch 4/100
# 994/994 [==============================] - 994s 1000ms/step - loss: 1.7642e-05 - mean_absolute_percentage_error: 61.0968 - mean_absolute_error: 0.0015 - val_loss: 1.3557e-06 - val_mean_absolute_percentage_error: 4.5940 - val_mean_absolute_error: 4.7301e-04
# Epoch 5/100
# 994/994 [==============================] - 991s 998ms/step - loss: 5.5573e-06 - mean_absolute_percentage_error: 36.1532 - mean_absolute_error: 7.7206e-04 - val_loss: 1.0784e-06 - val_mean_absolute_percentage_error: 4.1821 - val_mean_absolute_error: 4.1136e-04
# Epoch 6/100
# 994/994 [==============================] - 986s 992ms/step - loss: 0.0059 - mean_absolute_percentage_error: 318.2081 - mean_absolute_error: 0.0168 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 239.9584 - val_mean_absolute_error: 0.0281
# Epoch 7/100
# 994/994 [==============================] - 996s 1s/step - loss: 7.9175e-04 - mean_absolute_percentage_error: 193.9005 - mean_absolute_error: 0.0135 - val_loss: 5.4772e-05 - val_mean_absolute_percentage_error: 66.9600 - val_mean_absolute_error: 0.0033
# Epoch 8/100
# 994/994 [==============================] - 995s 1s/step - loss: 3.1239e-05 - mean_absolute_percentage_error: 43.1103 - mean_absolute_error: 0.0025 - val_loss: 2.2365e-05 - val_mean_absolute_percentage_error: 25.3350 - val_mean_absolute_error: 0.0020
# Epoch 9/100
# 994/994 [==============================] - 987s 994ms/step - loss: 1.9778e-05 - mean_absolute_percentage_error: 34.9931 - mean_absolute_error: 0.0020 - val_loss: 1.4673e-05 - val_mean_absolute_percentage_error: 34.9409 - val_mean_absolute_error: 0.0018
# Epoch 10/100
# 994/994 [==============================] - 1002s 1s/step - loss: 1.4091e-04 - mean_absolute_percentage_error: 70.5325 - mean_absolute_error: 0.0039 - val_loss: 1.4480e-05 - val_mean_absolute_percentage_error: 29.8028 - val_mean_absolute_error: 0.0018

# %%
# Save model
# Uncomment to save model

model_save_dir = 'models/RNN/05r/model'

model.save(model_save_dir)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_10_layer_call_fn, lstm_cell_10_layer_call_and_return_conditional_losses, lstm_cell_11_layer_call_fn, lstm_cell_11_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/RNN/05r/model\assets
# INFO:tensorflow:Assets written to: models/RNN/05r/model\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000102F97B74F0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x00000102F97B0640> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# IMPORTING SAVED MODEL

# %%
# Load model

model_dir = 'models/RNN/07_2/model'

model = tf.keras.models.load_model(model_dir)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1200, 256)         267264
#
#  lstm_1 (LSTM)               (None, 64)                82176
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 349,505
# Trainable params: 349,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# MODEL PERFORMANCE

# %%
# Evaluate model

val_performance = model.evaluate(Data.Val)
test_performance = model.evaluate(Data.Test)

print('Validation MSE_loss: {:.2f}'.format(val_performance[0]))
print('Validation MAPE:     {:.2f}'.format(val_performance[1]))
print('Validation MAE:      {:.2f}'.format(val_performance[2]))
print('Test MSE_loss:       {:.2f}'.format(test_performance[0]))
print('Test MAPE:           {:.2f}'.format(test_performance[1]))
print('Test MAE:            {:.2f}'.format(test_performance[2]))

# %% [markdown]
# INFERENCE

# %%
# Dataset generator
n = 10
m = 5
hop = 0.5
input_dim   = 30 * n
pred_dim    = 30 * n
shift       = pred_dim
batch_size  = 16
Data_inf        = DS(
                input_dim, 
                pred_dim, 
                shift, 
                skip=0.25, 
                hop=hop, 
                batch_size=batch_size,
                in_cols=['roll','heave','pitch','wave'],
                out_cols=['roll','heave','pitch','wave']
                )

# %%
def ARModel_Inference(x, y, OUT_dim = pred_dim*4, model=model):
    inp1 = x
    true_roll = y[:,:,0]
    pred_roll = []
    for i in range(OUT_dim):
        wave = y[:,i:i+1,-1:]
        INPUT = inp1
        OUT = model(INPUT)
        roll = tf.expand_dims(tf.cast(OUT, tf.float64), axis=1)
        HPW = y[:,i:i+1,1:]
        temp = tf.concat([roll, HPW], axis = -1)
        inp1 = tf.concat([inp1[:,1:,:], temp], axis=1)
        pred_roll.append(roll[:,:,0])

    pred_roll = tf.squeeze(tf.stack(pred_roll, axis=1), [-1]) 
    return true_roll, pred_roll


def get_inference(Data_inf, model=model, OUT_dim = pred_dim*4, save_dir=None):
    true_roll = []
    pred_roll = []
    inputs = []
    for x, y in Data_inf.take(2):
        t_r, p_r = ARModel_Inference(x, y, OUT_dim = OUT_dim, model=model)
        pred_roll.extend(p_r)
        true_roll.extend(t_r)
        inputs.extend(x)
        
    inputs = np.array(inputs)
    true_roll = np.array(true_roll)
    pred_roll = np.array(pred_roll)
        
    return inputs, true_roll, pred_roll
    
def save_inference(inputs, true_roll, pred_roll, save_dir):
    
    
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)
        
    inp_path = save_dir + '/inputs.csv'
    true_path = save_dir + '/true_roll.csv'
    pred_path = save_dir + '/pred_roll.csv'

    np.savetxt(inp_path, inputs[:,:,0], delimiter =", ")
    np.savetxt(true_path, true_roll, delimiter =", ")
    np.savetxt(pred_path, pred_roll, delimiter =", ")
    
def load_inference(folder):
    inputs    = np.genfromtxt(folder + '/inputs.csv', delimiter=', ', skip_header=0)
    true_roll = np.genfromtxt(folder + '/true_roll.csv', delimiter=', ', skip_header=0)
    pred_roll = np.genfromtxt(folder + '/pred_roll.csv', delimiter=', ', skip_header=0)
    
    return inputs, true_roll, pred_roll

# %%
val_dir = 'models/RNN/07_2/Val'
test_dir = 'models/RNN/07_2/Test'

# %%
test_in, test_true, test_pred = get_inference(Data_inf.Test, save_dir=test_dir)
# val_in, val_true, val_pred = get_inference(Data_inf.Val, save_dir=val_dir)

# %%
save_inference(val_in, val_true, val_pred, val_dir)

# %%
val_pred.shape
# Out:
# (128, 1200)

# %%
def plot_inference(inputs, true, pred, nos, cut=0.5, units='deg'):
    n = inputs.shape[-1]
    n_plots = len(nos)
    cut_ind = int(n*cut)
    
    fac = 180/np.pi if units=='deg' else 1
    
    plt.figure(figsize=(18, n_plots*5))
    
    w1_end = inputs.shape[1]
    w2_size = true.shape[-1]*cut_ind
    t1 = np.array(range(0, w1_end))*0.25
    t2 = np.array(range(w1_end, w1_end + cut_ind))*0.25
    
    for i, ind in enumerate(nos):
        plt.subplot(n_plots, 1, i+1)
        plt.plot(t1, inputs[ind]*fac, label='Input')
        plt.plot(t2, true[ind,:cut_ind]*fac, label='True_roll')
        plt.plot(t2, pred[ind,:cut_ind]*fac, label='Pred_roll')
        plt.ylabel(f"Roll angle ({units})")
        plt.legend()
    plt.xlabel("Time (s)")    
    plt.show()

# %%
plot_inference(test_in[:,:,0], test_true, test_pred, nos=[0,22,24,26], cut=1)
