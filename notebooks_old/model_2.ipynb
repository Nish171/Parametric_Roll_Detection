# %%
import os
os.chdir('..')

# %%
pwd
# Out:
# 'C:\\Users\\nimee\\OneDrive\\Documents\\DDP\\Parametric_Roll_Detection'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.data.Dataset import Dataset as DS
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# from src.models.Model_OneShotDNN import OneShotDNN

# %%
# Dataset generator
n = 10
m = 5
hop = 0.25
input_dim   = 30 * n
pred_dim    = 30 * m
shift       = pred_dim
batch_size  = 16
Data        = DS(
                input_dim, 
                pred_dim, 
                shift, 
                skip=0.25, 
                hop=hop, 
                batch_size=batch_size,
                in_cols=['roll']
                )

# %%
Data.Train.element_spec
# Out:
# (TensorSpec(shape=(None, 1200, 1), dtype=tf.float64, name=None),
#  TensorSpec(shape=(None, 600, 1), dtype=tf.float64, name=None))

# %%
# Loss functions
# Regression loss
MSE_loss = tf.keras.losses.MeanSquaredError()

# Metrics
# Regression metrics
MAPE = tf.keras.metrics.MeanAbsolutePercentageError()
MAE = tf.keras.metrics.MeanAbsoluteError()

# %%
INPUT_DIM = Data.xshape
OUTPUT_DIM = Data.yshape

# %%
print('Input dim:', INPUT_DIM)
print('Output dim:', OUTPUT_DIM)
# Out:
# Input dim: [1200, 1]
# Output dim: [600, 1]

# %%
norm = tf.keras.layers.Normalization(input_shape=INPUT_DIM, axis=-1)
x_ds = Data.Train.map(lambda x, y: x)
norm.adapt(x_ds)

# %%
norm.variance.numpy()
# Out:
# array([[[15.116447  ,  0.60266036]]], dtype=float32)

# %%
acti = 'tanh'

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=INPUT_DIM))
# model.add(norm)
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1024, activation=acti))
model.add(tf.keras.layers.Dense(1024, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(512, activation=acti))
model.add(tf.keras.layers.Dense(OUTPUT_DIM[0]))

# %%
opt = tf.keras.optimizers.Adam(learning_rate=5*0.001)
model.compile(optimizer=opt, loss=MSE_loss, metrics=[MAPE, MAE])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1200)              0
#
#  dense (Dense)               (None, 1024)              1229824
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 512)               262656
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dense_5 (Dense)             (None, 600)               307800
#
# =================================================================
# Total params: 3,637,336
# Trainable params: 3,637,336
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=10,
                                                    mode='min')

# %%
model.fit(Data.Train, epochs=100, validation_data=Data.Val, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 429/429 [==============================] - 25s 56ms/step - loss: 0.0054 - mean_absolute_percentage_error: 511.5655 - mean_absolute_error: 0.0351 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 584.3463 - val_mean_absolute_error: 0.0284
# Epoch 2/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0057 - mean_absolute_percentage_error: 443.3226 - mean_absolute_error: 0.0365 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 584.7862 - val_mean_absolute_error: 0.0301
# Epoch 3/100
# 429/429 [==============================] - 22s 50ms/step - loss: 0.0051 - mean_absolute_percentage_error: 458.9557 - mean_absolute_error: 0.0345 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 640.6414 - val_mean_absolute_error: 0.0296
# Epoch 4/100
# 429/429 [==============================] - 22s 52ms/step - loss: 0.0056 - mean_absolute_percentage_error: 483.3966 - mean_absolute_error: 0.0365 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 476.6034 - val_mean_absolute_error: 0.0259
# Epoch 5/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0049 - mean_absolute_percentage_error: 405.9194 - mean_absolute_error: 0.0339 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 585.0974 - val_mean_absolute_error: 0.0281
# Epoch 6/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0060 - mean_absolute_percentage_error: 527.4315 - mean_absolute_error: 0.0372 - val_loss: 0.0023 - val_mean_absolute_percentage_error: 399.8493 - val_mean_absolute_error: 0.0244
# Epoch 7/100
# 429/429 [==============================] - 22s 52ms/step - loss: 0.0044 - mean_absolute_percentage_error: 395.4788 - mean_absolute_error: 0.0326 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 570.7490 - val_mean_absolute_error: 0.0273
# Epoch 8/100
# 429/429 [==============================] - 24s 56ms/step - loss: 0.0047 - mean_absolute_percentage_error: 407.9589 - mean_absolute_error: 0.0333 - val_loss: 0.0023 - val_mean_absolute_percentage_error: 433.0182 - val_mean_absolute_error: 0.0245
# Epoch 9/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0048 - mean_absolute_percentage_error: 422.1363 - mean_absolute_error: 0.0335 - val_loss: 0.0023 - val_mean_absolute_percentage_error: 431.1655 - val_mean_absolute_error: 0.0242
# Epoch 10/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0046 - mean_absolute_percentage_error: 401.7318 - mean_absolute_error: 0.0331 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 515.3511 - val_mean_absolute_error: 0.0276
# Epoch 11/100
# 429/429 [==============================] - 23s 53ms/step - loss: 0.0050 - mean_absolute_percentage_error: 502.7573 - mean_absolute_error: 0.0350 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 491.8298 - val_mean_absolute_error: 0.0268
# Epoch 12/100
# 429/429 [==============================] - 28s 64ms/step - loss: 0.0047 - mean_absolute_percentage_error: 463.1766 - mean_absolute_error: 0.0336 - val_loss: 0.0022 - val_mean_absolute_percentage_error: 388.2019 - val_mean_absolute_error: 0.0240
# Epoch 13/100
# 429/429 [==============================] - 24s 55ms/step - loss: 0.0051 - mean_absolute_percentage_error: 499.6304 - mean_absolute_error: 0.0353 - val_loss: 0.0028 - val_mean_absolute_percentage_error: 519.6802 - val_mean_absolute_error: 0.0273
# Epoch 14/100
# 429/429 [==============================] - 23s 55ms/step - loss: 0.0054 - mean_absolute_percentage_error: 645.5762 - mean_absolute_error: 0.0374 - val_loss: 0.0036 - val_mean_absolute_percentage_error: 653.6608 - val_mean_absolute_error: 0.0317
# Epoch 15/100
# 429/429 [==============================] - 24s 56ms/step - loss: 0.0048 - mean_absolute_percentage_error: 578.7267 - mean_absolute_error: 0.0353 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 566.3478 - val_mean_absolute_error: 0.0271
# Epoch 16/100
# 429/429 [==============================] - 24s 57ms/step - loss: 0.0048 - mean_absolute_percentage_error: 616.8120 - mean_absolute_error: 0.0354 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 542.7595 - val_mean_absolute_error: 0.0267
# Epoch 17/100
# 429/429 [==============================] - 24s 57ms/step - loss: 0.0057 - mean_absolute_percentage_error: 887.7678 - mean_absolute_error: 0.0401 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 590.9799 - val_mean_absolute_error: 0.0265
# Epoch 18/100
# 429/429 [==============================] - 22s 52ms/step - loss: 0.0051 - mean_absolute_percentage_error: 853.5665 - mean_absolute_error: 0.0381 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 572.5157 - val_mean_absolute_error: 0.0256
# Epoch 19/100
# 429/429 [==============================] - 23s 54ms/step - loss: 0.0049 - mean_absolute_percentage_error: 810.4114 - mean_absolute_error: 0.0370 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 608.0482 - val_mean_absolute_error: 0.0262
# Epoch 20/100
# 429/429 [==============================] - 22s 52ms/step - loss: 0.0051 - mean_absolute_percentage_error: 786.6711 - mean_absolute_error: 0.0378 - val_loss: 0.0025 - val_mean_absolute_percentage_error: 556.8963 - val_mean_absolute_error: 0.0263
# Epoch 21/100
# 429/429 [==============================] - 23s 54ms/step - loss: 0.0050 - mean_absolute_percentage_error: 1035.5681 - mean_absolute_error: 0.0390 - val_loss: 0.0029 - val_mean_absolute_percentage_error: 638.7642 - val_mean_absolute_error: 0.0291
# Epoch 22/100
# 429/429 [==============================] - 23s 54ms/step - loss: 0.0051 - mean_absolute_percentage_error: 907.9512 - mean_absolute_error: 0.0385 - val_loss: 0.0026 - val_mean_absolute_percentage_error: 490.8265 - val_mean_absolute_error: 0.0266

# %%
Data.plot_example(49, model, max_plots=5)

# %%
for x, y in Data.Example(50):
    y_pred = model(x)
    print(x.shape)
    print(max(y[0,:]))
    print(y.shape, y_pred.shape)
    print(MAE(y, y_pred))
    plt.plot(y_pred[0,:], label='y')
    plt.show()
    break
# Out:
# (16, 1200, 2)
# tf.Tensor([6.91228834], shape=(1,), dtype=float64)
# (16, 600, 1) (16, 600)
# tf.Tensor(1.4001782, shape=(), dtype=float32)

# %%
for x, y in Data.Example(50):
    x_norm = norm(x)
    y_pred = model(x_norm)
    print(x_norm.shape)
    plt.plot(x[0,:,0], label='x')
    plt.plot(x_norm[0,:,0], label='x_norm')
    plt.plot(y_pred[0,:])
    plt.plot(y[0,:])
    plt.show()
    break
# Out:
# (16, 1200, 2)

# %%
oneshot_dnn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(INPUT_DIM,)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(OUTPUT_DIM, activation='linear')
])

# %%
MAX_EPOCHS_TRAINING = 50

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  lr_scheduler = tf.keras.callbacks.LearningRateScheduler(
      lambda epoch: 1e-5 * 10**(epoch / 4))

  model.compile(loss=MSE_loss,
                optimizer=tf.optimizers.Adam(learning_rate=1e-5),
                metrics=[MAPE, MAE])

  history = model.fit(window.Train, epochs=MAX_EPOCHS_TRAINING,
                      validation_data=window.Val,
                      callbacks=[early_stopping])
  return history

# %%
history_training = compile_and_fit(oneshot_dnn_model, data)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\nimee\OneDrive\Documents\DDP\Parametric_Roll_Detection\notebooks\model_2.ipynb Cell 15' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000014?line=0'>1</a> history_training = compile_and_fit(oneshot_dnn_model, data)
#
# c:\Users\nimee\OneDrive\Documents\DDP\Parametric_Roll_Detection\notebooks\model_2.ipynb Cell 14' in compile_and_fit(model, window, patience)
#       <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=7'>8</a> lr_scheduler = tf.keras.callbacks.LearningRateScheduler(
#       <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=8'>9</a>     lambda epoch: 1e-5 * 10**(epoch / 4))
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=10'>11</a> model.compile(loss=MSE_loss,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=11'>12</a>               optimizer=tf.optimizers.Adam(learning_rate=1e-5),
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=12'>13</a>               metrics=[MAPE, MAE])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=14'>15</a> history = model.fit(window.Train, epochs=MAX_EPOCHS_TRAINING,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=15'>16</a>                     validation_data=window.Val,
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=16'>17</a>                     callbacks=[early_stopping])
#      <a href='vscode-notebook-cell:/c%3A/Users/nimee/OneDrive/Documents/DDP/Parametric_Roll_Detection/notebooks/model_2.ipynb#ch0000013?line=17'>18</a> return history
#
# File c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\tensorflow\python\framework\func_graph.py:1147, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1144'>1145</a> except Exception as e:  # pylint:disable=broad-except
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1145'>1146</a>   if hasattr(e, "ag_error_metadata"):
# -> <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1146'>1147</a>     raise e.ag_error_metadata.to_exception(e)
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1147'>1148</a>   else:
#    <a href='file:///c%3A/Users/nimee/OneDrive/Documents/DDP/ddp/lib/site-packages/tensorflow/python/framework/func_graph.py?line=1148'>1149</a>     raise
#
# ValueError: in user code:
#
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "c:\Users\nimee\OneDrive\Documents\DDP\ddp\lib\site-packages\keras\losses.py", line 1329, in mean_squared_error
#         return backend.mean(tf.math.squared_difference(y_pred, y_true), axis=-1)
#
#     ValueError: Dimensions must be equal, but are 120 and 60 for '{{node mean_squared_error/SquaredDifference}} = SquaredDifference[T=DT_FLOAT](my_model/dense_4/BiasAdd, Cast)' with input shapes: [?,120,60], [?,60,1].

# %%
val_performance = model.evaluate(Data.Val)
test_performance = model.evaluate(Data.Test)
# Out:
# 53/53 [==============================] - 1s 23ms/step - loss: 5.6095 - mean_absolute_percentage_error: 453.1004 - mean_absolute_error: 1.2141
# 62/62 [==============================] - 2s 23ms/step - loss: 7.9224 - mean_absolute_percentage_error: 415.3475 - mean_absolute_error: 1.4855

# %%
print('Validation MSE_loss: {:.2f}'.format(val_performance[0]))
print('Validation MAPE:     {:.2f}'.format(val_performance[1]))
print('Validation MAE:      {:.2f}'.format(val_performance[2]))
print('Test MSE_loss:       {:.2f}'.format(test_performance[0]))
print('Test MAPE:           {:.2f}'.format(test_performance[1]))
print('Test MAE:            {:.2f}'.format(test_performance[2]))
# Out:
# Validation MSE_loss: 5.61
# Validation MAPE:     453.10
# Validation MAE:      1.21
# Test MSE_loss:       7.92
# Test MAPE:           415.35
# Test MAE:            1.49

# %%
model.save('models/oneshot_dnn_model')
# Out:
# INFO:tensorflow:Assets written to: models/oneshot_dnn_model\assets
